# %% [markdown]
# # EDA Project: Heart Prediction Dataset Analysis
# # Name of group Members -- Praveen,Janani,Monisha,Varsha.Vishwa
# # Group - 11th Group
# # Name of the file Heart Prediction Dataset.ipynb
# ## I. Project Setup
#
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
#Load the Heart Attack prediction data set 
df1=pd.read_csv("Heart Prediction Quantum Dataset_1.csv")

# %% [markdown]
# ## II. Data Import and Cleaning

# %% [markdown]
# ### Initial Data Inspection

# %% [markdown]
# # shape of the dataset # data types # Summary # first 5 rows

# %%
print("Checking the shape of the dataset : ")
df1.shape
# Out:
# Checking the shape of the dataset :
# (500, 8)

# %%
print("Type of the datatype is : ",type(df1))
# Out:
# Type of the datatype is :  <class 'pandas.core.frame.DataFrame'>

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      500 non-null    int64
#  1   Gender                   500 non-null    object
#  2   Blood Pressure           500 non-null    int64
#  3   Cholesterol              500 non-null    int64
#  4   Heart Rate               500 non-null    int64
#  5   Quantum Pattern Feature  500 non-null    float64
#  6   Current Heart Disease    500 non-null    object
#  7   Age with Gender          500 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 31.4+ KB
# None

# %%
print(df1.describe())
# Out:
#               Age      Gender  BloodPressure  Cholesterol  HeartRate  \
# count  504.000000  504.000000     503.000000   504.000000  504.00000
# mean    54.837302    0.466270     132.821074   221.289683   88.85119
# std     14.293199    0.499357      26.404149    44.051608   17.38603
# min     30.000000    0.000000      90.000000   150.000000   60.00000
# 25%     43.000000    0.000000     111.000000   182.750000   73.00000
# 50%     55.000000    0.000000     132.000000   221.000000   89.00000
# 75%     66.000000    1.000000     155.000000   258.250000  103.25000
# max     79.000000    1.000000     179.000000   299.000000  119.00000
#
#        QuantumPatternFeature  HeartDisease
# count             504.000000    504.000000
# mean                8.312299      0.599206
# std                 0.920742      0.490546
# min                 6.164692      0.000000
# 25%                 7.663130      0.000000
# 50%                 8.323064      1.000000
# 75%                 8.935999      1.000000
# max                10.784886      1.000000

# %%
print("\nFirst 5 Rows:")
df1.head() #top five data in the dataset
# Out:
# First 5 Rows:
#    Age  Gender  Blood Pressure  Cholesterol  Heart Rate  \
# 0   79  Female             168          230          73
# 1   79    Male              96          247         116
# 2   79    Male             118          195          74
# 3   79  Female             121          237          69
# 4   79  Female             144          292          91
#
#    Quantum Pattern Feature Current Heart Disease Age with Gender
# 0                 7.052413                   Yes       79 Female
# 1                 8.327116                   Yes         79 Male
# 2                 6.625696                   Yes         79 Male
# 3                 8.293940                   Yes       79 Female
# 4                 7.650543                   Yes       79 Female

# %%
print("Corelationship between the data",df1.corr)
# Out:
# Corelationship between the data <bound method DataFrame.corr of      Age  Gender  Blood Pressure  Cholesterol  Heart Rate  \
# 0     79  Female             168          230          73
# 1     79    Male              96          247         116
# 2     79    Male             118          195          74
# 3     79  Female             121          237          69
# 4     79  Female             144          292          91
# ..   ...     ...             ...          ...         ...
# 495   30  Female             158          186          82
# 496   30    Male             144          158          61
# 497   30  Female             101          242         109
# 498   30    Male             109          246          62
# 499   30  Female             113          153          82
#
#      Quantum Pattern Feature Current Heart Disease Age with Gender
# 0                   7.052413                   Yes       79 Female
# 1                   8.327116                   Yes         79 Male
# 2                   6.625696                   Yes         79 Male
# 3                   8.293940                   Yes       79 Female
# 4                   7.650543                   Yes       79 Female
# ..                       ...                   ...             ...
# 495                 7.236666                   Yes       30 Female
# 496                 7.361904                   Yes         30 Male
# 497                 9.004935                    No       30 Female
# 498                 7.613961                   Yes         30 Male
# 499                 6.693328                   Yes       30 Female
#
# [500 rows x 8 columns]>

# %% [markdown]
# ### Missing Values Handling

# %%
print("checking the null values or missing values ",df1.isnull().sum() )
# Out:
# checking the null values or missing values  Age                        0
# Gender                     0
# Blood Pressure             0
# Cholesterol                0
# Heart Rate                 0
# Quantum Pattern Feature    0
# Current Heart Disease      0
# Age with Gender            0
# dtype: int64

# %%
df1['Blood Pressure'].fillna(df1['Blood Pressure'].mean())
print("Updated dataset :",df1)
# Out:
# Updated dataset :      Age  Gender  Blood Pressure  Cholesterol  Heart Rate  \
# 0     79  Female             168          230          73
# 1     79    Male              96          247         116
# 2     79    Male             118          195          74
# 3     79  Female             121          237          69
# 4     79  Female             144          292          91
# ..   ...     ...             ...          ...         ...
# 495   30  Female             158          186          82
# 496   30    Male             144          158          61
# 497   30  Female             101          242         109
# 498   30    Male             109          246          62
# 499   30  Female             113          153          82
#
#      Quantum Pattern Feature Current Heart Disease Age with Gender
# 0                   7.052413                   Yes       79 Female
# 1                   8.327116                   Yes         79 Male
# 2                   6.625696                   Yes         79 Male
# 3                   8.293940                   Yes       79 Female
# 4                   7.650543                   Yes       79 Female
# ..                       ...                   ...             ...
# 495                 7.236666                   Yes       30 Female
# 496                 7.361904                   Yes         30 Male
# 497                 9.004935                    No       30 Female
# 498                 7.613961                   Yes         30 Male
# 499                 6.693328                   Yes       30 Female
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Duplicate Rows Removal

# %%
print("\n Duplicate rows:")
print(df1.duplicated().sum())
df1.drop_duplicates(inplace=True)  #Dropping the duplicate rows
# Out:
#  Duplicate rows:
# 0

# %% [markdown]
# ### Data Type Conversion

# %%
# its is not required since we have not used the datatime format

# %% [markdown]
# ## III. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# #### numerical columns

# %%
print("\nNumerical Summary:")
df1.describe() # count to check no of non empty values #Min #Max #stats of data
# Out:
# Numerical Summary:
#               Age  Blood Pressure  Cholesterol  Heart Rate  \
# count  500.000000      500.000000    500.00000  500.000000
# mean    54.864000      132.874000    221.50000   88.766000
# std     14.315004       26.418516     43.86363   17.417289
# min     30.000000       90.000000    150.00000   60.000000
# 25%     43.000000      111.000000    183.75000   73.000000
# 50%     55.000000      132.000000    221.00000   89.000000
# 75%     66.250000      155.000000    258.00000  104.000000
# max     79.000000      179.000000    299.00000  119.000000
#
#        Quantum Pattern Feature
# count               500.000000
# mean                  8.317407
# std                   0.919629
# min                   6.164692
# 25%                   7.675779
# 50%                   8.323064
# 75%                   8.935999
# max                  10.784886

# %%
print("\nMedians for numerical columns:")
print(df1.median(numeric_only=True))
# Out:
# Medians for numerical columns:
# Age                         55.000000
# Blood Pressure             132.000000
# Cholesterol                221.000000
# Heart Rate                  89.000000
# Quantum Pattern Feature      8.323064
# dtype: float64

# %%
print("\n mean for numerical columns:")
print(df1.mean(numeric_only=True))
# Out:
#  mean for numerical columns:
# Age                         54.864000
# Blood Pressure             132.874000
# Cholesterol                221.500000
# Heart Rate                  88.766000
# Quantum Pattern Feature      8.317407
# dtype: float64

# %%
print("\n skewness of the numerical columns:")
print(df1.skew())
# Out:
#  skewness of the numerical columns:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\Apps\Python\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\nanops.py:1240, in nanskew(values, axis, skipna, mask)
#    1239 if values.dtype.kind != "f":
# -> 1240     values = values.astype("f8")
#    1241     count = _get_counts(values.shape, mask, axis)
#
# ValueError: could not convert string to float: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 print("\n skewness of the numerical columns:")
# ----> 2 print(df1.skew())
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:11761, in DataFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#   11753 @doc(make_doc("skew", ndim=2))
#   11754 def skew(
#   11755     self,
#    (...)
#   11759     **kwargs,
#   11760 ):
# > 11761     result = super().skew(axis, skipna, numeric_only, **kwargs)
#   11762     if isinstance(result, Series):
#   11763         result = result.__finalize__(self, method="skew")
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\generic.py:12442, in NDFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#   12435 def skew(
#   12436     self,
#   12437     axis: Axis | None = 0,
#    (...)
#   12440     **kwargs,
#   12441 ) -> Series | float:
# > 12442     return self._stat_function(
#   12443         "skew", nanops.nanskew, axis, skipna, numeric_only, **kwargs
#   12444     )
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\nanops.py:92, in disallow.__call__.<locals>._f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
# ---> 92         raise TypeError(e) from e
#      93     raise
#
# TypeError: could not convert string to float: 'Female'

# %% [markdown]
# #### categorical columns

# %%
#not working need to check it 
print("\nCategorical Summary:")
for col in df1.select_dtypes(include=['object']).columns:
    print(f"\nValue counts for column '{col}':\n{df1[col].value_counts()}")
# Out:
# Categorical Summary:
#
# Value counts for column 'Gender':
# Gender
# Female    266
# Male      234
# Name: count, dtype: int64
#
# Value counts for column 'Current Heart Disease':
# Current Heart Disease
# Yes    300
# No     200
# Name: count, dtype: int64
#
# Value counts for column 'Age with Gender':
# Age with Gender
# 57 Female    11
# 54 Male      10
# 64 Male      10
# 62 Male      10
# 77 Female    10
#              ..
# 33 Male       1
# 49 Male       1
# 39 Male       1
# 67 Female     1
# 72 Male       1
# Name: count, Length: 98, dtype: int64

# %%
HeartDisease_counts = df1['Heart Disease'].value_counts()
# Out:
#   Cell In[77], line 1
#     Heart Disease_counts = df1['Heart Disease'].value_counts()
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### histograms or density plots for numerical

# %% [markdown]
# ##### HISTOGRAM

# %%
df1.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# ##### Bar plots

# %%
print("\n Bar plots of categorical features:")
for col in df1.select_dtypes(include=['object']).columns:
    sns.countplot(x=col, data=df1)
    plt.title(f'Bar Plot of {col}')
    plt.show()
# Out:
#  Bar plots of categorical features:

# %%
print("\n Bar plots of categorical features:")
for col in df1.select_dtypes(include=['object']).columns:
    sns.countplot(x=col, data=df1)
    plt.title(f'Bar Plot of  Numerical features {col}')
    plt.show()
# Out:
#  Bar plots of categorical features:

# %% [markdown]
# ##### Box Plots (Outlier Detection):

# %%
print("\n Box plots to find outlayers finding : ")
sns.boxplot(data=df1[['Age','Cholesterol','Blood Pressure','Heart Rate','Quantum Pattern Feature']],palette='coolwarm')
plt.xticks(rotation=90)
plt.title("Box Plot of features")
plt.show()
# Out:
#  Box plots to find outlayers finding :

# %% [markdown]
# ##### Scatter Plots (Relationship between Numerical Features)

# %%
print("\n Scatter plot of age and cholesterol:")
print(sns.scatterplot(data=df1,x='Age',y='Cholesterol'))
# Out:
#  Scatter plot of age and cholesterol:
# Axes(0.125,0.11;0.775x0.77)

# %%
print("\n Scatter plot of Blood Pressure  and  Cholesterol:")
print(sns.scatterplot(data=df1,x='Blood Pressure',y='Cholesterol'))
# Out:
#  Scatter plot of Blood Pressure  and  Cholesterol:
# Axes(0.125,0.11;0.775x0.77)

# %%
print("\n Heatmap of correlation map:")
map=df1.corr()
sns.heatmap(map,annot=True,cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
#  Heatmap of correlation map:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 2
#       1 print("\n Heatmap of correlation map:")
# ----> 2 map=df1.corr()
#       3 sns.heatmap(map,annot=True,cmap='coolwarm')
#       4 plt.title('Feature Correlation Heatmap')
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %% [markdown]
# ### Group Analysis

# %%
print("\n Group analysis by gender:")
print(df1.groupby('Gender')['Age'].mean())
# Out:
#  Group analysis by gender:
# Gender
# Female    55.093985
# Male      54.602564
# Name: Age, dtype: float64

# %%
print("\n Group analysis by Cholesterol:")
print(df1.groupby('Cholesterol')['Age'].mean())
# Out:
#  Group analysis by Cholesterol:
# Cholesterol
# 150    41.000000
# 151    65.500000
# 152    56.750000
# 153    48.000000
# 154    52.333333
#          ...
# 295    47.750000
# 296    53.666667
# 297    52.166667
# 298    74.000000
# 299    56.000000
# Name: Age, Length: 142, dtype: float64

# %%
print("\n Group analysis by Blood Pressure:")
print(df1.groupby('Blood Pressure')['Age'].mean())
# Out:
#  Group analysis by Blood Pressure:
# Blood Pressure
# 90     50.900000
# 91     56.857143
# 92     56.500000
# 93     46.857143
# 94     56.000000
#          ...
# 175    60.125000
# 176    55.500000
# 177    58.400000
# 178    52.250000
# 179    50.333333
# Name: Age, Length: 89, dtype: float64

# %%
print("\n### Group analysis by Current Heart Disease:")
print(df1.groupby('Current Heart Disease')['Age'].mean())
# Out:
# ### Group analysis by Current Heart Disease:
# Current Heart Disease
# No     50.34
# Yes    57.88
# Name: Age, dtype: float64

# %%
print("\n### Group analysis by Current Heart Disease:")
print(df1.groupby('Current Heart Disease')['Cholesterol'].mean())
# Out:
# ### Group analysis by Current Heart Disease:
# Current Heart Disease
# No     244.230000
# Yes    206.346667
# Name: Cholesterol, dtype: float64

# %%
table = pd.pivot_table(df1, values=['Age'], index=['Cholesterol', 'Quantum Pattern Feature'],aggfunc={'Age': ["min", "max", "mean"]})
print("\n Pivot table:")
print(table)
# Out:
#  Pivot table:
#                                     Age
#                                     max  mean min
# Cholesterol Quantum Pattern Feature
# 150         9.151229                 41  41.0  41
# 151         6.898421                 62  62.0  62
#             7.296842                 69  69.0  69
# 152         6.515717                 72  72.0  72
#             6.714608                 68  68.0  68
# ...                                  ..   ...  ..
# 298         8.935573                 77  77.0  77
# 299         8.449829                 70  70.0  70
#             8.648836                 48  48.0  48
#             8.945035                 68  68.0  68
#             10.492135                38  38.0  38
#
# [500 rows x 3 columns]

# %% [markdown]
# #### Feature Analysis

# %% [markdown]
# ##### pair plot

# %%
print ("\n Pairplot:",sns.pairplot(df1[['Age','Cholesterol','Current Heart Disease','Blood Pressure']],height=1.5))
# Out:
#  Pairplot: <seaborn.axisgrid.PairGrid object at 0x000002879BBC2000>

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Quantum Pattern Feature', y='Age', data=df1)
plt.title("Box Plot of Age vs. Quantum Pattern Feature")
plt.show()

# %%
correlation_matrix = df1.corr()
print(correlation_matrix['Current Heart Disease'].sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 correlation_matrix = df1.corr()
#       2 print(correlation_matrix['Current Heart Disease'].sort_values(ascending=False))
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File C:\Apps\Python\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %%
# Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df1['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Gender Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df1)
plt.title('Gender Distribution')
plt.show()

# %%
# Quantum Pattern Feature Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df1['Quantum Pattern Feature'], kde=True)
plt.title('Quantum Pattern Feature Distribution')
plt.show()

# %%
# Target Variable Distribution (Heart Disease)
plt.figure(figsize=(6, 4))
sns.countplot(x='Current Heart Disease', data=df1)
plt.title('Heart Disease Distribution')
plt.show()

# %%
# Relationship between features and target variable
sns.pairplot(df1, hue='Current Heart Disease')
plt.show()

# %%
# Feature Details:

print("\nFeature Details:")
for col in df1.columns:
    print(f"\nFeature: {col}")
    print(f"  - Data Type: {df1[col].dtype}")
    print(f"  - Unique Values: {df1[col].nunique()}")
    print(f"  - Unique Value Examples: {df1[col].unique()[:5]}") # Display first 5 unique values
    if df1[col].dtype != 'object': #avoid statistical details for object datatypes.
        print(f"  - Min: {df1[col].min()}")
        print(f"  - Max: {df1[col].max()}")
        print(f"  - Mean: {df1[col].mean()}")
        print(f"  - Standard Deviation: {df1[col].std()}")
# Out:
# Feature Details:
#
# Feature: Age
#   - Data Type: int64
#   - Unique Values: 50
#   - Unique Value Examples: [68 58 44 72 37]
#   - Min: 30
#   - Max: 79
#   - Mean: 54.85370741482966
#   - Standard Deviation: 14.298055070454728
#
# Feature: Gender
#   - Data Type: int64
#   - Unique Values: 2
#   - Unique Value Examples: [1 0]
#   - Min: 0
#   - Max: 1
#   - Mean: 0.46893787575150303
#   - Standard Deviation: 0.4995349987821973
#
# Feature: BloodPressure
#   - Data Type: float64
#   - Unique Values: 89
#   - Unique Value Examples: [105.  97.  93. 145. 114.]
#   - Min: 90.0
#   - Max: 179.0
#   - Mean: 132.82329317269077
#   - Standard Deviation: 26.451065247257656
#
# Feature: Cholesterol
#   - Data Type: int64
#   - Unique Values: 142
#   - Unique Value Examples: [191 249 190 183 166]
#   - Min: 150
#   - Max: 299
#   - Mean: 221.27655310621242
#   - Standard Deviation: 43.95273647358891
#
# Feature: HeartRate
#   - Data Type: int64
#   - Unique Values: 60
#   - Unique Value Examples: [107  89  82 101 103]
#   - Min: 60
#   - Max: 119
#   - Mean: 88.78156312625251
#   - Standard Deviation: 17.405464127321423
#
# Feature: QuantumPatternFeature
#   - Data Type: float64
#   - Unique Values: 498
#   - Unique Value Examples: [8.36224069 9.24900153 7.94254206 6.49515512 7.65390012]
#   - Min: 6.164692103
#   - Max: 10.78488616
#   - Mean: 8.313367311687374
#   - Standard Deviation: 0.9198556284439269
#
# Feature: HeartDisease
#   - Data Type: int64
#   - Unique Values: 2
#   - Unique Value Examples: [1 0]
#   - Min: 0
#   - Max: 1
#   - Mean: 0.6012024048096193
#   - Standard Deviation: 0.4901423417487294
