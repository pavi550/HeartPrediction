# %% [markdown]
# # EDA Project: Heart Prediction Dataset Analysis
# # Name of group Members -- Praveen,Janani,Monisha,Varsha.Vishwa
# # Group - 11th Group
# # Name of the file Heart Prediction Dataset.ipynb
# ## I. Project Setup
#
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
#Load the Heart Attack prediction data set 
df1=pd.read_csv("Heart Prediction Quantum Dataset.csv")

# %% [markdown]
# ## II. Data Import and Cleaning

# %% [markdown]
# ### Initial Data Inspection

# %% [markdown]
# # shape of the dataset # data types # Summary # first 5 rows

# %%
print("Checking the shape of the dataset : ")
df1.shape
# Out:
# Checking the shape of the dataset :
# (504, 7)

# %%
print("Type of the datatype is : ",type(df1))
# Out:
# Type of the datatype is :  <class 'pandas.core.frame.DataFrame'>

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    504 non-null    int64
#  1   Gender                 504 non-null    int64
#  2   BloodPressure          503 non-null    float64
#  3   Cholesterol            504 non-null    int64
#  4   HeartRate              504 non-null    int64
#  5   QuantumPatternFeature  504 non-null    float64
#  6   HeartDisease           504 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 27.7 KB
# None

# %%
print(df1.describe())
# Out:
#               Age      Gender  BloodPressure  Cholesterol  HeartRate  \
# count  504.000000  504.000000     503.000000   504.000000  504.00000
# mean    54.837302    0.466270     132.821074   221.289683   88.85119
# std     14.293199    0.499357      26.404149    44.051608   17.38603
# min     30.000000    0.000000      90.000000   150.000000   60.00000
# 25%     43.000000    0.000000     111.000000   182.750000   73.00000
# 50%     55.000000    0.000000     132.000000   221.000000   89.00000
# 75%     66.000000    1.000000     155.000000   258.250000  103.25000
# max     79.000000    1.000000     179.000000   299.000000  119.00000
#
#        QuantumPatternFeature  HeartDisease
# count             504.000000    504.000000
# mean                8.312299      0.599206
# std                 0.920742      0.490546
# min                 6.164692      0.000000
# 25%                 7.663130      0.000000
# 50%                 8.323064      1.000000
# 75%                 8.935999      1.000000
# max                10.784886      1.000000

# %%
print("\nFirst 5 Rows:")
df1.head() #top five data in the dataset
# Out:
# First 5 Rows:
#    Age  Gender  BloodPressure  Cholesterol  HeartRate  QuantumPatternFeature  \
# 0   68       1          105.0          191        107               8.362241
# 1   58       0           97.0          249         89               9.249002
# 2   44       0           93.0          190         82               7.942542
# 3   72       1           93.0          183        101               6.495155
# 4   37       0          145.0          166        103               7.653900
#
#    HeartDisease
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1

# %%
print("Corelationship between the data",df1.corr)
# Out:
# Corelationship between the data <bound method DataFrame.corr of      Age  Gender  BloodPressure  Cholesterol  HeartRate  \
# 0     68       1          105.0          191        107
# 1     58       0           97.0          249         89
# 2     44       0           93.0          190         82
# 3     72       1           93.0          183        101
# 4     37       0          145.0          166        103
# ..   ...     ...            ...          ...        ...
# 499   55       0          174.0          249         89
# 500   72       0          135.0          152         91
# 501   66       0          105.0          276         98
# 502   41       0          164.0          248        114
# 503   59       0          107.0          157        101
#
#      QuantumPatternFeature  HeartDisease
# 0                 8.362241             1
# 1                 9.249002             0
# 2                 7.942542             1
# 3                 6.495155             1
# 4                 7.653900             1
# ..                     ...           ...
# 499              10.492950             0
# 500               6.515717             1
# 501               9.159122             0
# 502               9.067889             0
# 503               7.337650             1
#
# [504 rows x 7 columns]>

# %% [markdown]
# ### Missing Values Handling

# %%
print("checking the null values or missing values ",df1.isnull().sum() )
# Out:
# checking the null values or missing values  Age                      0
# Gender                   0
# BloodPressure            1
# Cholesterol              0
# HeartRate                0
# QuantumPatternFeature    0
# HeartDisease             0
# dtype: int64

# %%
df1['BloodPressure'].fillna(df1['BloodPressure'].mean())
print("Updated dataset :",df1)
# Out:
# Updated dataset :      Age  Gender  BloodPressure  Cholesterol  HeartRate  \
# 0     68       1          105.0          191        107
# 1     58       0           97.0          249         89
# 2     44       0           93.0          190         82
# 3     72       1           93.0          183        101
# 4     37       0          145.0          166        103
# ..   ...     ...            ...          ...        ...
# 499   55       0          174.0          249         89
# 500   72       0          135.0          152         91
# 501   66       0          105.0          276         98
# 502   41       0          164.0          248        114
# 503   59       0          107.0          157        101
#
#      QuantumPatternFeature  HeartDisease
# 0                 8.362241             1
# 1                 9.249002             0
# 2                 7.942542             1
# 3                 6.495155             1
# 4                 7.653900             1
# ..                     ...           ...
# 499              10.492950             0
# 500               6.515717             1
# 501               9.159122             0
# 502               9.067889             0
# 503               7.337650             1
#
# [504 rows x 7 columns]

# %% [markdown]
# ### Duplicate Rows Removal

# %%
print("\n Duplicate rows:")
print(df1.duplicated().sum())
df1.drop_duplicates(inplace=True)  #Dropping the duplicate rows
# Out:
#  Duplicate rows:
# 5

# %% [markdown]
# ### Data Type Conversion

# %%
# its is not required since we have not used the datatime format

# %% [markdown]
# ## III. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# #### numerical columns

# %%
print("\nNumerical Summary:")
df1.describe() # count to check no of non empty values #Min #Max #stats of data
# Out:
# Numerical Summary:
#               Age      Gender  BloodPressure  Cholesterol   HeartRate  \
# count  499.000000  499.000000     498.000000   499.000000  499.000000
# mean    54.853707    0.468938     132.823293   221.276553   88.781563
# std     14.298055    0.499535      26.451065    43.952736   17.405464
# min     30.000000    0.000000      90.000000   150.000000   60.000000
# 25%     43.000000    0.000000     111.000000   183.000000   73.000000
# 50%     55.000000    0.000000     131.500000   221.000000   89.000000
# 75%     66.000000    1.000000     155.000000   258.000000  103.500000
# max     79.000000    1.000000     179.000000   299.000000  119.000000
#
#        QuantumPatternFeature  HeartDisease
# count             499.000000    499.000000
# mean                8.313367      0.601202
# std                 0.919856      0.490142
# min                 6.164692      0.000000
# 25%                 7.667603      0.000000
# 50%                 8.319011      1.000000
# 75%                 8.933010      1.000000
# max                10.784886      1.000000

# %%
print("\nMedians for numerical columns:")
print(df1.median(numeric_only=True))
# Out:
# Medians for numerical columns:
# Age                       55.000000
# Gender                     0.000000
# BloodPressure            131.500000
# Cholesterol              221.000000
# HeartRate                 89.000000
# QuantumPatternFeature      8.319011
# HeartDisease               1.000000
# dtype: float64

# %%
print("\n mean for numerical columns:")
print(df1.mean(numeric_only=True))
# Out:
#  mean for numerical columns:
# Age                       54.853707
# Gender                     0.468938
# BloodPressure            132.823293
# Cholesterol              221.276553
# HeartRate                 88.781563
# QuantumPatternFeature      8.313367
# HeartDisease               0.601202
# dtype: float64

# %%
print("\n  skewness of the numerical columns:")
print(df1.skew())
# Out:
#   skewness of the numerical columns:
# Age                     -0.108460
# Gender                   0.124865
# BloodPressure            0.080164
# Cholesterol              0.103386
# HeartRate               -0.007654
# QuantumPatternFeature    0.081781
# HeartDisease            -0.414613
# dtype: float64

# %% [markdown]
# #### categorical columns

# %%
#not working need to check it 
print("\nCategorical Summary:")
for col in df1.select_dtypes(include=['object']).columns:
    print(f"\nValue counts for column '{col}':\n{df1[col].value_counts()}")
# Out:
# Categorical Summary:

# %%
HeartDisease_counts = df1['HeartDisease'].value_counts()

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### histograms or density plots for numerical

# %% [markdown]
# ##### HISTOGRAM

# %%
df1.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# ##### Bar plots

# %%
print("\n Bar plots of categorical features:")
for col in df1.select_dtypes(include=['object']).columns:
    sns.countplot(x=col, data=df1)
    plt.title(f'Bar Plot of {col}')
    plt.show()
# Out:
#  Bar plots of categorical features:

# %%
print("\n Bar plots of categorical features:")
for col in df1.select_dtypes(include=['object']).columns:
    sns.countplot(x=col, data=df1)
    plt.title(f'Bar Plot of  Numerical features {col}')
    plt.show()
# Out:
#  Bar plots of categorical features:

# %% [markdown]
# ##### Box Plots (Outlier Detection):

# %%
print("\n Box plots to find outlayers finding : ")
sns.boxplot(data=df1[['Age','Cholesterol','BloodPressure','HeartRate','QuantumPatternFeature']],palette='coolwarm')
plt.xticks(rotation=90)
plt.title("Box Plot of features")
plt.show()
# Out:
#  Box plots to find outlayers finding :

# %% [markdown]
# ##### Scatter Plots (Relationship between Numerical Features)

# %%
print("\n Scatter plot of age and cholesterol:")
print(sns.scatterplot(data=df1,x='Age',y='Cholesterol'))
# Out:
#  Scatter plot of age and cholesterol:
# Axes(0.125,0.11;0.775x0.77)

# %%
print("\n Scatter plot of Blood Pressure  and  Cholesterol:")
print(sns.scatterplot(data=df1,x='BloodPressure',y='Cholesterol'))
# Out:
#  Scatter plot of Blood Pressure  and  Cholesterol:
# Axes(0.125,0.11;0.775x0.77)

# %%
print("\n Heatmap of correlation map:")
map=df1.corr()
sns.heatmap(map,annot=True,cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
#  Heatmap of correlation map:

# %% [markdown]
# ### Group Analysis

# %%
print("\n Group analysis by gender:")
print(df1.groupby('Gender')['Age'].mean())
# Out:
#  Group analysis by gender:
# Gender
# 0    55.075472
# 1    54.602564
# Name: Age, dtype: float64

# %%
print("\n Group analysis by Cholesterol:")
print(df1.groupby('Cholesterol')['Age'].mean())
# Out:
#  Group analysis by Cholesterol:
# Cholesterol
# 150    41.000000
# 151    65.500000
# 152    56.750000
# 153    48.000000
# 154    52.333333
#          ...
# 295    47.750000
# 296    53.666667
# 297    52.166667
# 298    74.000000
# 299    56.000000
# Name: Age, Length: 142, dtype: float64

# %%
print("\n Group analysis by BloodPressure:")
print(df1.groupby('BloodPressure')['Age'].mean())
# Out:
#  Group analysis by BloodPressure:
# BloodPressure
# 90.0     50.900000
# 91.0     56.857143
# 92.0     56.500000
# 93.0     46.857143
# 94.0     56.000000
#            ...
# 175.0    60.125000
# 176.0    55.500000
# 177.0    58.400000
# 178.0    52.250000
# 179.0    50.333333
# Name: Age, Length: 89, dtype: float64

# %%
print("\n### Group analysis by HeartDisease:")
print(df1.groupby('HeartDisease')['Age'].mean())
# Out:
# ### Group analysis by HeartDisease:
# HeartDisease
# 0    50.366834
# 1    57.830000
# Name: Age, dtype: float64

# %%
print("\n### Group analysis by HeartDisease:")
print(df1.groupby('HeartDisease')['Cholesterol'].mean())
# Out:
# ### Group analysis by HeartDisease:
# HeartDisease
# 0    244.291457
# 1    206.010000
# Name: Cholesterol, dtype: float64

# %%
table = pd.pivot_table(df1, values=['Gender', 'Age'], index=['Cholesterol', 'QuantumPatternFeature'],aggfunc={'Gender': "mean",'Age': ["min", "max", "mean"]})
print("\n Pivot table:")
print(table)
# Out:
#  Pivot table:
#                                   Age           Gender
#                                   max  mean min   mean
# Cholesterol QuantumPatternFeature
# 150         9.151229               41  41.0  41    0.0
# 151         6.898421               62  62.0  62    0.0
#             7.296842               69  69.0  69    0.0
# 152         6.515717               72  72.0  72    0.0
#             6.714608               68  68.0  68    0.0
# ...                                ..   ...  ..    ...
# 298         8.935573               77  77.0  77    0.0
# 299         8.449829               70  70.0  70    1.0
#             8.648836               48  48.0  48    1.0
#             8.945035               68  68.0  68    0.0
#             10.492135              38  38.0  38    0.0
#
# [498 rows x 4 columns]

# %% [markdown]
# #### Feature Analysis

# %% [markdown]
# ##### pair plot

# %%
print ("\n Pairplot:",sns.pairplot(df1[['Age','Cholesterol','HeartDisease','BloodPressure']],height=1.5))
# Out:
#  Pairplot: <seaborn.axisgrid.PairGrid object at 0x00000275C0CE9010>

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='QuantumPatternFeature', y='Age', data=df1)
plt.title("Box Plot of Age vs. QuantumPatternFeature")
plt.show()

# %%
correlation_matrix = df1.corr()
print(correlation_matrix['HeartDisease'].sort_values(ascending=False))
# Out:
# HeartDisease             1.000000
# Age                      0.255840
# Gender                  -0.013789
# HeartRate               -0.097556
# BloodPressure           -0.115057
# Cholesterol             -0.426899
# QuantumPatternFeature   -0.774957
# Name: HeartDisease, dtype: float64

# %%
# Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df1['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Gender Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Gender', data=df1)
plt.title('Gender Distribution')
plt.show()

# %%
# Quantum Pattern Feature Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df1['QuantumPatternFeature'], kde=True)
plt.title('Quantum Pattern Feature Distribution')
plt.show()

# %%
# Target Variable Distribution (Heart Disease)
plt.figure(figsize=(6, 4))
sns.countplot(x='HeartDisease', data=df1)
plt.title('Heart Disease Distribution')
plt.show()

# %%
# Relationship between features and target variable
sns.pairplot(df1, hue='HeartDisease')
plt.show()

# %%
# Feature Details:

print("\nFeature Details:")
for col in df1.columns:
    print(f"\nFeature: {col}")
    print(f"  - Data Type: {df1[col].dtype}")
    print(f"  - Unique Values: {df1[col].nunique()}")
    print(f"  - Unique Value Examples: {df1[col].unique()[:5]}") # Display first 5 unique values
    if df1[col].dtype != 'object': #avoid statistical details for object datatypes.
        print(f"  - Min: {df1[col].min()}")
        print(f"  - Max: {df1[col].max()}")
        print(f"  - Mean: {df1[col].mean()}")
        print(f"  - Standard Deviation: {df1[col].std()}")
# Out:
# Feature Details:
#
# Feature: Age
#   - Data Type: int64
#   - Unique Values: 50
#   - Unique Value Examples: [68 58 44 72 37]
#   - Min: 30
#   - Max: 79
#   - Mean: 54.85370741482966
#   - Standard Deviation: 14.298055070454728
#
# Feature: Gender
#   - Data Type: int64
#   - Unique Values: 2
#   - Unique Value Examples: [1 0]
#   - Min: 0
#   - Max: 1
#   - Mean: 0.46893787575150303
#   - Standard Deviation: 0.4995349987821973
#
# Feature: BloodPressure
#   - Data Type: float64
#   - Unique Values: 89
#   - Unique Value Examples: [105.  97.  93. 145. 114.]
#   - Min: 90.0
#   - Max: 179.0
#   - Mean: 132.82329317269077
#   - Standard Deviation: 26.451065247257656
#
# Feature: Cholesterol
#   - Data Type: int64
#   - Unique Values: 142
#   - Unique Value Examples: [191 249 190 183 166]
#   - Min: 150
#   - Max: 299
#   - Mean: 221.27655310621242
#   - Standard Deviation: 43.95273647358891
#
# Feature: HeartRate
#   - Data Type: int64
#   - Unique Values: 60
#   - Unique Value Examples: [107  89  82 101 103]
#   - Min: 60
#   - Max: 119
#   - Mean: 88.78156312625251
#   - Standard Deviation: 17.405464127321423
#
# Feature: QuantumPatternFeature
#   - Data Type: float64
#   - Unique Values: 498
#   - Unique Value Examples: [8.36224069 9.24900153 7.94254206 6.49515512 7.65390012]
#   - Min: 6.164692103
#   - Max: 10.78488616
#   - Mean: 8.313367311687374
#   - Standard Deviation: 0.9198556284439269
#
# Feature: HeartDisease
#   - Data Type: int64
#   - Unique Values: 2
#   - Unique Value Examples: [1 0]
#   - Min: 0
#   - Max: 1
#   - Mean: 0.6012024048096193
#   - Standard Deviation: 0.4901423417487294
